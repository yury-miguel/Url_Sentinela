# %%
# Importação das bibliotecas necessárias

import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from lightgbm import LGBMClassifier
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score, PrecisionRecallDisplay

# %%
pip install lightgbm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Caminho do arquivo extraido
dataset_extraido = "../dados/dataset_phishing/PhiUSIIL_Phishing_URL_Dataset.csv"

# Carregamento dos dados usando o pandas
dataframe = pd.read_csv(dataset_extraido)

# Removendo as colunas insignificante para o algoritmo 'FILENAME', 'URL', 'DOMAIN' como já vimos no notebook da análise exploratória
dataframe = dataframe.drop(columns=['FILENAME', 'URL', 'Domain'])

# Exibe os 10 primeiros registros dos dados
dataframe.head(10)
# Out:
#    URLLength  DomainLength  IsDomainIP  TLD  URLSimilarityIndex  \
# 0         31            24           0  com               100.0
# 1         23            16           0   de               100.0
# 2         29            22           0   uk               100.0
# 3         26            19           0  com               100.0
# 4         33            26           0  org               100.0
# 5         30            23           0  org               100.0
# 6         25            18           0  com               100.0
# 7         25            18           0  com               100.0
# 8         29            22           0   in               100.0
# 9         18            11           0  org               100.0
#
#    CharContinuationRate  TLDLegitimateProb  URLCharProb  TLDLength  \
# 0              1.000000           0.522907     0.061933          3
# 1              0.666667           0.032650     0.050207          2
# ...

# %%
# Verificando balanceamento das classes alvo
print("Distribuição das classes:")
print(dataframe['label'].value_counts(normalize=True))
# Out:
# Distribuição das classes:
# label
# 1    0.571895
# 0    0.428105
# Name: proportion, dtype: float64

# %%
"""
Como a coluna TLD pode ser relevante e tem 695 valores únicos dos totais 235.795
agrupamos os valores menos frequentes em uma unica categoria e convertemos para numeros ordinais
"""
# Agrupando valores menos frequentes com minimo de 10 ocorrências para a coluna TLD
tld_contagem = dataframe['TLD'].value_counts()
limite = 10 
tld_raros = tld_contagem[tld_contagem < limite].index
dataframe['TLD'] = dataframe['TLD'].replace(tld_raros, 'Outros')

# Transformando dados da coluna TLD que era object em variaveis categóricas
codificador = OrdinalEncoder()
dataframe['TLD'] = codificador.fit_transform(dataframe[['TLD']])

# %%
"""
Como a coluna Title pode ser relevante e tem 197.874 valores únicos dos totais 235.795, indica que os dados são altamente cardinalizados
e que valores únicos são numerosos, então vamos usar o comprimento do titulo como feature e adicionar hashes com uma quantidade fixa de inteiros 
para reduzir a dimensionalidade, pois adicionamos numeros inteiros para as categorias com a mesma unicidade.
"""
# Adicionando comprimento do titulo como caracteristica
dataframe['Comprimento_Titulo'] = dataframe['Title'].str.len()

# Configurando o HashingVectorizer
hashing = HashingVectorizer(n_features=100)
titulo_hash = hashing.fit_transform(dataframe['Title'].fillna(""))

# Adiciona a coluna do titulo como hashes
titulo_hash_df = pd.DataFrame(titulo_hash.toarray(), columns=[f'titulo_hash_{i}' for i in range(100)])
dataframe = pd.concat([dataframe, titulo_hash_df], axis=1)

# Removemos a coluna original
dataframe.drop(columns='Title', inplace=True)

# %% [markdown]
# ## Label; 0 phishing, 1 legítimo

# %%
# Mapa de calor da correlação
plt.figure(figsize=(12,8))
sns.heatmap(dataframe.corr(), cmap='coolwarm', annot=False, linewidths=0.5)
plt.title("Mapa de Calor das Correlações")
plt.show()

# %%
# Separa os dados de entrada e saida
dataframe = dataframe.drop_duplicates()

X = dataframe.drop(columns='label')
y = dataframe['label']

# Preserva o nome das colunas
colunas_originais = X.columns

# Eliminação das caracteristicas de baixas variâncias
selecao = VarianceThreshold(threshold=0.01)
X_reduzido = selecao.fit_transform(X)

# Verificar as colunas que restaram
colunas_selecionadas = colunas_originais[selecao.get_support()]

# Identificação das variaveis mais importantes
rf = RandomForestClassifier(random_state=42)
rf.fit(X_reduzido, y)
importantes = rf.feature_importances_

# Exibindo as 10 caracteristicas mais importantes
caracteristicas_importantes = pd.Series(importantes, index=colunas_selecionadas).sort_values(ascending=False)
print("10 caracteristicas mais importantes")
print(caracteristicas_importantes.head(10))
# Out:
# 10 caracteristicas mais importantes
# URLSimilarityIndex    0.190653
# NoOfExternalRef       0.170983
# LineOfCode            0.111100
# NoOfImage             0.107820
# NoOfSelfRef           0.091437
# NoOfJS                0.071644
# NoOfCSS               0.049570
# HasDescription        0.031791
# LargestLineLength     0.027952
# HasSocialNet          0.023461
# dtype: float64

# %%
# Vamos remover as colunas que possuem alta correlação, pois pode viciar nosso modelo
dataframe = dataframe.drop(columns=['NoOfExternalRef', 'URLSimilarityIndex'])

# Criamos um novo dataframe com os dados modificados após a engenharia
novo_dataset = "../dados/dataset_phishing/dados_projetados.csv"
dataframe.to_csv(novo_dataset, index=False)
print(f"Novo Dataset salvo em {novo_dataset}")
# Out:
# Novo Dataset salvo em ../dados/dataset_phishing/dados_projetados.csv

# %%
# Divisão do dataset, separação em treino e teste
y = dataframe['label']
X_treino, X_teste, y_treino, y_teste = train_test_split(X_reduzido, y, test_size=0.3, random_state=42, stratify=y)

# %%
# Criação de pipeline para Random Forest
rf_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', RandomForestClassifier(max_depth=5, n_estimators=100, random_state=42))
])

# Criação de pipeline para LGBM
lgbm_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LGBMClassifier(lambda_l1=1.0, lambda_l2=1.0, random_state=42))
])

# %%
# Treinar e avaliar Random Forest
rf_pipeline.fit(X_treino, y_treino)
rf_predicoes = rf_pipeline.predict(X_teste)
print("Random Forest - Avaliação:")
print(classification_report(y_teste, rf_predicoes))
print("Acurácia:", accuracy_score(y_teste, rf_predicoes))

# Treinar e avaliar LightGBM
lgbm_pipeline.fit(X_treino, y_treino)
lgbm_predicoes = lgbm_pipeline.predict(X_teste)
print("LightGBM - Avaliação:")
print(classification_report(y_teste, lgbm_predicoes))
print("Acurácia:", accuracy_score(y_teste, lgbm_predicoes))
# Out:
# Random Forest - Avaliação:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     30245
#            1       1.00      1.00      1.00     40455
#
#     accuracy                           1.00     70700
#    macro avg       1.00      1.00      1.00     70700
# weighted avg       1.00      1.00      1.00     70700
#
# Acurácia: 0.99992927864215
# [LightGBM] [Warning] lambda_l1 is set=1.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Warning] lambda_l1 is set=1.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Info] Number of positive: 94395, number of negative: 70569
# ...

# %%
# Previsões no conjunto de treinamento
rf_treino_pred = rf_pipeline.predict(X_treino)
lgbm_treino_pred = lgbm_pipeline.predict(X_treino)

# Métricas no treinamento - Random Forest
print("Random Forest - Treinamento:")
print(classification_report(y_treino, rf_treino_pred))
print("Acurácia:", accuracy_score(y_treino, rf_treino_pred))

# Métricas no treinamento - LightGBM
print("LightGBM - Treinamento:")
print(classification_report(y_treino, lgbm_treino_pred))
print("Acurácia:", accuracy_score(y_treino, lgbm_treino_pred))
# Out:
# [LightGBM] [Warning] lambda_l1 is set=1.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# Random Forest - Treinamento:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     70569
#            1       1.00      1.00      1.00     94395
#
#     accuracy                           1.00    164964
#    macro avg       1.00      1.00      1.00    164964
# weighted avg       1.00      1.00      1.00    164964
#
# Acurácia: 0.9999393807133677
# LightGBM - Treinamento:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     70569
#            1       1.00      1.00      1.00     94395
#
#     accuracy                           1.00    164964
#    macro avg       1.00      1.00      1.00    164964
# weighted avg       1.00      1.00      1.00    164964
#
# ...

# %%
# Função para plotar a matriz de confusão
def plot_matriz_confusao(y_verdadeiro, y_pred, titulo):
    cm = confusion_matrix(y_verdadeiro, y_pred)
    plt.figure(figsize=(6,4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Phishing', 'Legitimo'], yticklabels=['Phishing', 'Legitimo'])
    plt.xlabel('Preditor')
    plt.ylabel('Atual')
    plt.title(f'Matriz de Confusão - {titulo}')


# Função para plotar a curva ROC
def plot_roc_curva(y_verdadeiro, y_proba, titulo):
    fpr, tpr, _ = roc_curve(y_verdadeiro, y_proba)
    auc_score = roc_auc_score(y_verdadeiro, y_proba)
    plt.figure(figsize=(6, 4))
    plt.plot(fpr, tpr, label=f'AUC = {auc_score:.4f}', color='blue')
    plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Curva ROC - {titulo}')
    plt.legend(loc='lower right')
    plt.grid()
    plt.show()

# Função para comparar métricas de desempenho
def plot_performance(metricas, modelos, titulo):
    plt.figure(figsize=(10, 6))
    for modelo, valores in modelos.items():
        plt.plot(metricas, valores, marker='o', label=modelo)
    plt.xlabel('Métricas')
    plt.ylabel('Valor')
    plt.ylim(0.98, 1.01)
    plt.title(titulo)
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
# Plotando a matriz de confusão para os dois modelos
plot_matriz_confusao(y_teste, rf_predicoes, 'Random Forest')
plot_matriz_confusao(y_teste, lgbm_predicoes, 'LightGBM')

# %%
# Predição das probabilidades
rf_proba = rf_pipeline.predict_proba(X_teste)[:, 1]
lgbm_proba = lgbm_pipeline.predict_proba(X_teste)[:, 1]

# Plotando curva ROC para os dois modelos
plot_roc_curva(y_teste, rf_proba, 'Random Forest')
plot_roc_curva(y_teste, lgbm_proba, 'LightGBM')
# Out:
# [LightGBM] [Warning] lambda_l1 is set=1.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0

# %%
# Realizando validação cruzada (5-Fold)
rf_scores = cross_val_score(rf_pipeline, X_treino, y_treino, cv=5, scoring='accuracy')
lgbm_scores = cross_val_score(lgbm_pipeline, X_treino, y_treino, cv=5, scoring='accuracy')

# Printando os scores para Random Forest
print("Random Forest - Validação Cruzada (5-Fold):")
print("Scores para cada fold:", rf_scores)
print("Acurácia média:", rf_scores.mean())
print("Desvio padrão:", rf_scores.std())

# Printando os scores para LightGBM
print("\nLightGBM - Validação Cruzada (5-Fold):")
print("Scores para cada fold:", lgbm_scores)
print("Acurácia média:", lgbm_scores.mean())
print("Desvio padrão:", lgbm_scores.std())
# Out:
# [LightGBM] [Warning] lambda_l1 is set=1.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Warning] lambda_l1 is set=1.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Info] Number of positive: 75516, number of negative: 56455
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010746 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4539
# [LightGBM] [Info] Number of data points in the train set: 131971, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.572217 -> initscore=0.290901
# [LightGBM] [Info] Start training from score 0.290901
# ...

# %%
# Calculando métricas para os modelos
rf_metricas = [
    accuracy_score(y_teste, rf_predicoes),
    precision_score(y_teste, rf_predicoes),
    recall_score(y_teste, rf_predicoes),
    f1_score(y_teste, rf_predicoes)
]

lgbm_metricas = [
    accuracy_score(y_teste, lgbm_predicoes),
    precision_score(y_teste, lgbm_predicoes),
    recall_score(y_teste, lgbm_predicoes),
    f1_score(y_teste, lgbm_predicoes)
]

metricas_nomes = ['Acurácia', 'Precisão', 'Recall', 'F1-Score']

# Comparação entre os modelos
plot_performance(metricas_nomes, {'Random Forest': rf_metricas, 'LightGBM': lgbm_metricas}, 'Comparação de Desempenho')
